# %%
from pymongo import MongoClient
import os
import pandas as pd
import numpy as np

# Connect to MongoDB
mongo_client = MongoClient(os.getenv("mongodb+srv://kenil:12121212@cluster0.azdvmbj.mongodb.net/?appName=Cluster0"))

# Access the database and collection
db = mongo_client['kenil']
collection = db['Cement-Strength']

# Fetch data into a DataFrame
cursor = collection.find()

# Print cursor information for debugging
print("Number of documents in cursor:", collection.count_documents({}))

# Convert cursor to list of documents
documents = list(cursor)

# Print number of documents retrieved
print("Number of documents retrieved:", len(documents))

# Create DataFrame
df = pd.DataFrame(documents)

# Replace "na" with np.nan if necessary
df.replace({"na": np.nan}, inplace=True)

# Print the DataFrame to check the content
print(df.head())  # Print the first few rows for inspection
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[4], line 17
#      14 cursor = collection.find()
#      16 # Print cursor information for debugging
# ---> 17 print("Number of documents in cursor:", collection.count_documents({}))
#      19 # Convert cursor to list of documents
#      20 documents = list(cursor)
#
# File ~/anaconda3/lib/python3.10/site-packages/pymongo/collection.py:1899, in Collection.count_documents(self, filter, session, comment, **kwargs)
#    1896         return 0
#    1897     return result["n"]
# -> 1899 return self._retryable_non_cursor_read(_cmd, session, _Op.COUNT)
#
# File ~/anaconda3/lib/python3.10/site-packages/pymongo/collection.py:1910, in Collection._retryable_non_cursor_read(self, func, session, operation)
#    1908 client = self.__database.client
#    1909 with client._tmp_session(session) as s:
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import pandas as pd
import numpy as np

uri = "mongodb+srv://kenil:12121212@cluster0.azdvmbj.mongodb.net/dbname?ssl=true"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

# Specify the database and collection
database_name = "kenil"
collection_name = "Cement-strength"
db = client[database_name]
collection = db[collection_name]

# Query the collection
cursor = collection.find()

# Print cursor information for debugging
print("Number of documents in cursor:", collection.count_documents({}))

# Convert cursor

# Convert cursor to list of documents
documents = list(cursor)

# Print number of documents retrieved
print("Number of documents retrieved:", len(documents))

# Create DataFrame
df = pd.DataFrame(documents)

# Replace "na" with np.nan if necessary
df.replace({"na": np.nan}, inplace=True)

# Print the DataFrame to check the content
print(df.head())  # Print the first few rows for inspection
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Number of documents in cursor: 1030
# Number of documents retrieved: 1030
#                         _id  Cement (component 1)(kg in a m^3 mixture)  \
# 0  668f5f16b831d0aadabb108d                                      332.5
# 1  668f5f16b831d0aadabb108e                                      198.6
# 2  668f5f16b831d0aadabb1092                                      266.0
# 3  668f5f16b831d0aadabb1094                                      198.6
# 4  668f5f16b831d0aadabb1095                                      198.6
#
#    Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                              142.5
# 1                                              132.4
# 2                                              114.0
# 3                                              132.4
# 4                                              132.4
#
#    Fly Ash (component 3)(kg in a m^3 mixture)  \
# ...

# %%
def export_collection_as_dataframe(collection_name, db_name):
        uri = "mongodb+srv://kenil:21212121@cluster0.azdvmbj.mongodb.net/?appName=Cluster0"
        client = MongoClient(uri)
        db = client[db_name]
        collection = db[collection_name]
        # Fetch data into a DataFrame
        cursor = collection.find()
        documents = list(cursor)
        df = pd.DataFrame(documents)
        # Replace "na" with np.nan if necessary
        df.replace({"na": np.nan}, inplace=True)

        return df
print(export_collection_as_dataframe(collection_name="Cement-strength",db_name="kenil"))
# Out:
#                            _id  Cement (component 1)(kg in a m^3 mixture)  \
# 0     668f5f16b831d0aadabb108d                                      332.5
# 1     668f5f16b831d0aadabb108e                                      198.6
# 2     668f5f16b831d0aadabb1092                                      266.0
# 3     668f5f16b831d0aadabb1094                                      198.6
# 4     668f5f16b831d0aadabb1095                                      198.6
# ...                        ...                                        ...
# 1025  668f5f16b831d0aadabb145f                                      145.4
# 1026  668f5f16b831d0aadabb1470                                      304.8
# 1027  668f5f16b831d0aadabb1471                                      150.9
# 1028  668f5f16b831d0aadabb147b                                      298.1
# 1029  668f5f16b831d0aadabb147e                                      325.6
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# ...

# %%
uri = "mongodb+srv://kenil:12121212@cluster0.azdvmbj.mongodb.net/?appName=Cluster0"
client = MongoClient(uri, server_api=ServerApi('1'))
db = client['kenil']
collection = db['Cement-strength']
# Fetch data into a DataFrame
cursor = collection.find()
documents = list(cursor)
df = pd.DataFrame(documents)
# Replace "na" with np.nan if necessary
df.replace({"na": np.nan}, inplace=True)
print(df)
# Out:
#                            _id  Cement (component 1)(kg in a m^3 mixture)  \
# 0     668f5f16b831d0aadabb108a                                      540.0
# 1     668f5f16b831d0aadabb108b                                      540.0
# 2     668f5f16b831d0aadabb108c                                      332.5
# 3     668f5f16b831d0aadabb108d                                      332.5
# 4     668f5f16b831d0aadabb108e                                      198.6
# ...                        ...                                        ...
# 1025  668f5f16b831d0aadabb148b                                      276.4
# 1026  668f5f16b831d0aadabb148c                                      322.2
# 1027  668f5f16b831d0aadabb148d                                      148.5
# 1028  668f5f16b831d0aadabb148e                                      159.1
# 1029  668f5f16b831d0aadabb148f                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# ...
